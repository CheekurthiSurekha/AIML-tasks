# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Universities.csv")
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#Mean value of SAT score
np.mean(df["SAT"])
# Out:
# 1266.44

# %%
#Median value of SAT score
np.median(df["SAT"])
# Out:
# 1285.0

# %%
#Standard deviation of data
np.std(df["GradRate"])
# Out:
# 8.874773236539623

# %%
#Find the variance
np.var(df["SFRatio"])
# Out:
# 15.881599999999999

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %% [markdown]
# ###visualization

# %% [markdown]
# #bar chart - categorical data
#
# #histogram - continous data
#
# #box plot - continous data
#
# #histogram with kde curve - continous data
#
# #names - nominal data
#
# #gender, subjects - categorical data

# %%
#visualize the gradrate using histogram
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,3))
plt.title("Graduation Rate")
plt.hist(df["GradRate"])
# Out:
# (array([2., 2., 0., 1., 2., 0., 3., 4., 4., 7.]),
#  array([67., 70., 73., 76., 79., 82., 85., 88., 91., 94., 97.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ###visualization using boxplot

# %%
s=[20,15,10,25,30,35,28,40,45,60]
scores=pd.Series(s)
scores
# Out:
# 0    20
# 1    15
# 2    10
# 3    25
# 4    30
# 5    35
# 6    28
# 7    40
# 8    45
# 9    60
# dtype: int64

# %%
plt.boxplot(scores)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x236b8b592e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x236b8b59880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x236b8b58b00>],
#  'medians': [<matplotlib.lines.Line2D at 0x236b8b59d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x236b8b59fa0>],
#  'means': []}

# %%
s=[20,15,10,25,30,35,28,40,45,60,120,150]
scores=pd.Series(s)
scores
# Out:
# 0      20
# 1      15
# 2      10
# 3      25
# 4      30
# 5      35
# 6      28
# 7      40
# 8      45
# 9      60
# 10    120
# 11    150
# dtype: int64

# %%
plt.boxplot(scores,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x236b8d4e3f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x236b8d4e990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x236b8d4e0f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x236b8d4edb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x236b8d4f020>],
#  'means': []}

# %%
#visualization of data from university dataset
df=pd.read_csv("universities.csv")
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.figure(figsize=(6,2))
plt.title("Bx plot for SAT Score")
plt.boxplot(df["SAT"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x236be2777d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x236be277ce0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x236be2774d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x236be2981a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x236be298380>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
plt.title("Bx plot for SAT Score")
plt.boxplot(df["GradRate"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x236be2d1d60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x236be2d2210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x236be2d1af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x236be2d2690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x236be2d2930>],
#  'means': []}
